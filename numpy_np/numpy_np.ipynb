# %%
import numpy as np
# from jedi.inference.utils import to_list
# from numpy.conftest import dtype

# %%
a = np.array([[1,2,3], [4,5,6]])

# %%
a
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
b = [[2], [4]]
add = a*b
sum = a+b
print(add,sum, sep='\n')
# Out:
# [[ 2  4  6]
#  [16 20 24]]
# [[ 3  4  5]
#  [ 8  9 10]]

# %%
defa = add * sum
defa
# Out:
# array([[  6,  16,  30],
#        [128, 180, 240]])

# %%
defa
# Out:
# array([[  6,  16,  30],
#        [128, 180, 240]])

# %%
a = np.array([[1,2], [3,4]])
b = [1,3]
c = [[1], [3]]

# %%
sum = a*b
sum
# Out:
# array([[ 1,  6],
#        [ 3, 12]])

# %%
sum = a*c
sum
# Out:
# array([[ 1,  2],
#        [ 9, 12]])

# %%
matrix = [[1,2,3],[4,5,6]]#,[7,8,9]\
matrix
# Out:
# [[1, 2, 3], [4, 5, 6]]

# %%
matrix
matrix = np.transpose(matrix)
matrix, len(matrix)
rows = len(matrix)
cols = len(matrix[0])

# %%
# Есть матрица, нужно ее транспонировать

# %%
arr_2 = matrix
arr_2.ndim, len(arr_2), arr_2.size, arr_2.dtype, type(arr_2),
# Out:
# (2, 3, 6, dtype('int64'), numpy.ndarray)

# %%
matrix2 = np.empty((matrix.ndim, len(matrix)), dtype=int)
for i in range(rows):
    for j in range(cols):
        matrix2[j][i] = matrix[i][j]
print(matrix2)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
matrix2, matrix2.tolist(), len(matrix)
# Out:
# (array([[1, 2, 3],
#         [4, 5, 6]]),
#  [[1, 2, 3], [4, 5, 6]],
#  3)

# %%
ar = list([1,2,3])
type(ar)
# Out:
# list

# %%
np.array(ar)
# Out:
# array([1, 2, 3])

# %%
matrix
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
emp = np.empty((rows, cols), dtype=int)
emp[0][0]/10
# Out:
# np.float64(48103633726.2)

# %%
a = np.array([[1,2], [3,4]])
b = [1,3]
c = [[1], [3]]

# %%
print(a*b)
# Out:
# [[ 1  6]
#  [ 3 12]]

# %%
print(a*c)
# Out:
# [[ 1  2]
#  [ 9 12]]
