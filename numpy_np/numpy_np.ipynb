# %%
import numpy as np

# %%
a = np.array([[1,2,3], [4,5,6]])

# %%
a
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
b = [[2], [4]]
add = a*b
sum = a+b
print(add,sum, sep='\n')
# Out:
# [[ 2  4  6]
#  [16 20 24]]
# [[ 3  4  5]
#  [ 8  9 10]]

# %%
defa = add * sum
defa
# Out:
# array([[  6,  16,  30],
#        [128, 180, 240]])

# %%
defa
# Out:
# array([[  6,  16,  30],
#        [128, 180, 240]])

# %%
a = np.array([[1,2], [3,4]])
b = [1,3]
c = [[1], [3]]

# %%
sum = a*b
sum
# Out:
# array([[ 1,  6],
#        [ 3, 12]])

# %%
sum = a*c
sum
# Out:
# array([[ 1,  2],
#        [ 9, 12]])

# %%
matrix = [[1,2,3],[4,5,6],[7,8,9]]

# %%
matrix = np.transpose(matrix)
matrix
# Out:
# array([[1, 4, 7],
#        [2, 5, 8],
#        [3, 6, 9]])

# %%
# Есть матрица, нужно ее транспонировать

# %%
matrix[1][1] = 5
matrix2 = np.array([])
# for i in len(matrix):
#     print()

# %%
for i in range(len(matrix)):
    print(i, matrix[i])
    for j in range(len(matrix[i])):
        print(j, matrix[j])
        matrix2[i][j] = matrix[i][j]
        print(matrix2)
# Out:
# 0 [1 4 7]
# 0 [1 4 7]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 5
#       3 for j in range(len(matrix[i])):
#       4     print(j, matrix[j])
# ----> 5     matrix2[i][j] = matrix[i][j]
#       6     print(matrix2)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
