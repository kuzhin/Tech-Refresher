# %%
import numpy as np

# %%
a = np.array([[1,2,3], [4,5,6]])

# %%
a
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
b = [[2], [4]]
add = a*b
sum = a+b
print(add,sum, sep='\n')
# Out:
# [[ 2  4  6]
#  [16 20 24]]
# [[ 3  4  5]
#  [ 8  9 10]]

# %%
defa = add * sum
defa
# Out:
# array([[  6,  16,  30],
#        [128, 180, 240]])

# %%
defa
# Out:
# array([[  6,  16,  30],
#        [128, 180, 240]])

# %%
a = np.array([[1,2], [3,4]])
b = [1,3]
c = [[1], [3]]

# %%
sum = a*b
sum
# Out:
# array([[ 1,  6],
#        [ 3, 12]])

# %%
sum = a*c
sum
# Out:
# array([[ 1,  2],
#        [ 9, 12]])

# %%
matrix = [[1,2,3],[4,5,6],[7,8,9]]

# %%
matrix = np.transpose(matrix)
matrix
# Out:
# array([[1, 4, 7],
#        [2, 5, 8],
#        [3, 6, 9]])

# %%
import time

# %%
def one():
    start = time.time()
    a = 1+1
    end = time.time()
    diff = end - start
    return a, start,end,
print(one(
# Out:
# (2, 1766507469.3557167, 1766507469.3557167)
