# %%
import numpy as np

# %%
a = np.array([[1,2,3], [4,5,6]])

# %%
a
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
b = [[2], [4]]
add = a*b
sum = a+b
print(add,sum, sep='\n')
# Out:
# [[ 2  4  6]
#  [16 20 24]]
# [[ 3  4  5]
#  [ 8  9 10]]

# %%
defa = add * sum
defa
# Out:
# array([[  6,  16,  30],
#        [128, 180, 240]])

# %%
defa
# Out:
# array([[  6,  16,  30],
#        [128, 180, 240]])
