# %%
import random
def one(curr):
    for i in 100:


    yield curr

curr = 0
print(one(curr))

# %%
class father:
    def __init__(self, param):
        self.a = param

class child(father):
    def __init__(self, param):
        super().__init__(param)
        self.b = param

obj = child(22)
print("%d %d" % (obj.a, obj.b))
# Out:
# 22 22
